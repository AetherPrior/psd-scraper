# %%
import pandas as pd 
import numpy as np
from pandas.io.json import json_normalize

## Selecting  a PS station
Name = 'Remote'
## Select branch filter
branches = ['A7','Any']

df = pd.read_json(r'full.json')
df.drop(['StationId','AccomodationDesc','stipendforpg','Scholarship','CompanyId','stipend'],axis=1)
# Out:
#                                       Tags  TotalProject       City  \
# 0                                      Any             3  Hyderabad
# 1    A1 , A2 , A3 , A4 , A7 , A8 , AA , AB             1    Tirora
# 2                                      Any             1  Ahmedabad
# 3                                  A1 , A4             1      Halol
# 4                                  A1 , A4             1      Halol
# ..                                     ...           ...        ...
# 388                                     A7             1  Bangalore
# 389                                     A7             1  Bangalore
# 390                                     A7             1  Bangalore
# 391                                     A7             1  Bangalore
# 392                                     A7             1  Bangalore
#
#                                            CompanyName  ProjectIndustryDomain  \
# 0    Access Livelihoods Consulting India, Ltd. - So...                    3.0
# 1                                          Adani Power                    2.0
# 2                                          Adani Power                    2.0
# 3    Aditya Birla Chemicals - (SCM) -  Industry Ben...                    1.0
# 4    Aditya Birla Chemicals - (SCM) - Modelling and...                    1.0
# ..                                                 ...                    ...
# 388  Wipro - Attendance capturing system using GPS ...                    5.0
# 389                        Wipro - Chatbot development                    5.0
# 390         Wipro - Data analytics for decision making                    5.0
# 391              Wipro - Independent assessment engine                    5.0
# 392  Wipro - Online written examination system usin...                    5.0
#
#        IndustryDomain                                              projs
# 0    Finance and Mgmt  [{'StationId': 4680, 'CompanyId': 4386, 'Total...
# 1          Mechanical  [{'StationId': 47, 'CompanyId': 4, 'TotalProje...
# 2          Mechanical  [{'StationId': 315, 'CompanyId': 4, 'TotalProj...
# 3            Chemical  [{'StationId': 4572, 'CompanyId': 4278, 'Total...
# 4            Chemical  [{'StationId': 4571, 'CompanyId': 4277, 'Total...
# ..                ...                                                ...
# 388                IT  [{'StationId': 4475, 'CompanyId': 4181, 'Total...
# 389                IT  [{'StationId': 4476, 'CompanyId': 4182, 'Total...
# 390                IT  [{'StationId': 4477, 'CompanyId': 4183, 'Total...
# 391                IT  [{'StationId': 4478, 'CompanyId': 4184, 'Total...
# 392                IT  [{'StationId': 4474, 'CompanyId': 4180, 'Total...
#
# [393 rows x 7 columns]

# %%
def matcher(x):
    for i in branches:
        if x.find(i):
            return i
        else:
            return np.NaN

# %%
df2 = df[df['Tags'].apply(matcher).notna()].dropna(axis=0)
df2 = df2[df2['CompanyName'].str.contains(Name)]
print(df2)
# Out:
#      StationId               Tags  stipend AccomodationDesc  stipendforpg  \
# 194       4592  A3 , A7 , A8 , AA        0   Not Applicable             0
# 295       2663                Any        0   Not Applicable             0
#
#      Scholarship  CompanyId  TotalProject       City  \
# 194            0       4298             1  Hyderabad
# 295            0       2390             1    Jodhpur
#
#                                            CompanyName  ProjectIndustryDomain  \
# 194  Jochebed Tech Solutions -API\u0026apos;s for R...                    5.0
# 295                     Regional Remote Sensing Centre                    7.0
#
#         IndustryDomain                                              projs
# 194                 IT  [{'StationId': 4592, 'CompanyId': 4298, 'Total...
# 295  Govt Research Lab  [{'StationId': 2663, 'CompanyId': 2390, 'Total...

# %%
Projects = df2['projs']
Project = []
for i in Projects.tolist():
    for j in i:
        Project.append(j['details'])
print(Project)
# Out:
# [[{'ProjectId': 12434, 'TotalReqdStudents': 1, 'ProjectId1': 12434, 'projectTitle': 'API for Remote monitoring and control of IoT devices', 'CompanyId': 4298, 'StationId': 4592, 'PSType': 1, 'BatchId': 10, 'PBDescription': 'API for Remote monitoring and control of IoT devices', 'TotalReqdStudents1': 1, 'GeneralMinCGPA': '0', 'GeneralMaxCGPA': '0', 'CreateDate': '/Date(1588652825713)/', 'IsActive': True, 'Degree': 1, 'PSTypeFor': 1, 'BatchIdFor': 10, 'Filleddate': 'May  5 2020  9:57AM', 'Tags': 'A3 , A7 , A8 , AA', 'Filledby': 'PDC', 'TotalProject': 1}], [{'ProjectId': 11138, 'TotalReqdStudents': 10, 'ProjectId1': 11138, 'CompanyId': 2390, 'StationId': 2663, 'PSType': 1, 'BatchId': 10, 'PBDescription': '1) Advanced Digital Image Processing Techniques - Machine learning, Big Data Analytics, Artificial Intelligence etc. 2) Hyperspectral Data Analysis for Characterizing Various Natural Resources(Vegetation, Soil, Water, Air & Mineral) Note - Interest in working with hyperspectral data, knowledge of image data format & its processing. Acquaintance with ENVI/IDL Python or comparable image analysis tools is desirable3) Microwave Image Processing', 'TotalReqdStudents1': 10, 'GeneralMinCGPA': '0', 'GeneralMaxCGPA': '0', 'CreateDate': '/Date(1570256210627)/', 'IsActive': True, 'Degree': 1, 'PSTypeFor': 1, 'BatchIdFor': 10, 'Filleddate': 'Oct  5 2019 11:46AM', 'Tags': 'Any', 'Filledby': 'PDC', 'TotalProject': 1}], [{'ProjectId': 9964, 'TotalReqdStudents': 10, 'ProjectId1': 9964, 'projectTitle': 'CS work', 'CompanyId': 2390, 'StationId': 2663, 'PSType': 1, 'BatchId': 9, 'PBDescription': 'System Dynamics based Approach for Environmental Modelling. (Note â\x80\x93 Interest in working in modeling especially in environmental parameters is desirable)Hyperspectral Data Analysis for Characterizing Various Natural Resources  (Vegetation, Soil, Water, Air & Mineral) (Note â\x80\x93 Interest in working with hyperspectral data, knowledge of image data format & its processing.  Acquaintance with ENVI/IDL/Python or comparable image analysis tools is desirable)Advanced Digital Image Processing Techniques â\x80\x93 Machine learning,  Big Data Analytics, Artificial Intelligence  etc.Microwave Image Processing', 'TotalReqdStudents1': 10, 'GeneralMinCGPA': '0', 'GeneralMaxCGPA': '0', 'CreateDate': '/Date(1549274172483)/', 'IsActive': True, 'Degree': 1, 'PSTypeFor': 1, 'BatchIdFor': 9, 'Filleddate': 'Feb  4 2019  3:26PM', 'Tags': 'A3 , A7', 'Filledby': 'PDC', 'TotalProject': 1}], [{'ProjectId': 8038, 'TotalReqdStudents': 5, 'ProjectId1': 8038, 'projectTitle': 'Remote sensing related projects', 'CompanyId': 2390, 'StationId': 2663, 'PSType': 1, 'BatchId': 8, 'PBDescription': 'Remote sensing related projects', 'TotalReqdStudents1': 5, 'GeneralMinCGPA': '0', 'GeneralMaxCGPA': '0', 'CreateDate': '/Date(1521371177070)/', 'IsActive': True, 'Degree': 1, 'PSTypeFor': 1, 'BatchIdFor': 8, 'Filleddate': 'Mar 18 2018  4:36PM', 'Tags': 'A3 , A7', 'Filledby': 'PDC', 'TotalProject': 1}], [{'ProjectId': 6149, 'TotalReqdStudents': 5, 'ProjectId1': 6149, 'CompanyId': 2390, 'StationId': 2663, 'PSType': 1, 'BatchId': 7, 'PBDescription': 'System Dynamics based Approach for Environmental Modelling.Hyperspectral Data Analysis for Characterizing Various Natural Resources (Vegetation, Soil, Water, Air & Mineral)', 'TotalReqdStudents1': 5, 'GeneralMinCGPA': '0', 'GeneralMaxCGPA': '0', 'CreateDate': '/Date(1488172939913)/', 'IsActive': True, 'Degree': 1, 'PSTypeFor': 1, 'BatchIdFor': 7, 'Filleddate': 'Feb 27 2017 10:52AM', 'Tags': 'Any', 'Filledby': 'PDC', 'TotalProject': 1}]]

# %%
gen = [json_normalize(j).loc[:,['ProjectId','TotalReqdStudents','projectTitle','PBDescription']] for j in Project]
##stuff highly customized here, you'll need to recode
gen = [j[0]['PBDescription'] for j in Project]
print(gen)

#deets = [json_normalize(j).loc[:,'PBDescription'].tolist() for j in Project] ##may not work

#print(deets)
# Out:
# ['API for Remote monitoring and control of IoT devices', '1) Advanced Digital Image Processing Techniques - Machine learning, Big Data Analytics, Artificial Intelligence etc. 2) Hyperspectral Data Analysis for Characterizing Various Natural Resources(Vegetation, Soil, Water, Air & Mineral) Note - Interest in working with hyperspectral data, knowledge of image data format & its processing. Acquaintance with ENVI/IDL Python or comparable image analysis tools is desirable3) Microwave Image Processing', 'System Dynamics based Approach for Environmental Modelling. (Note â\x80\x93 Interest in working in modeling especially in environmental parameters is desirable)Hyperspectral Data Analysis for Characterizing Various Natural Resources  (Vegetation, Soil, Water, Air & Mineral) (Note â\x80\x93 Interest in working with hyperspectral data, knowledge of image data format & its processing.  Acquaintance with ENVI/IDL/Python or comparable image analysis tools is desirable)Advanced Digital Image Processing Techniques â\x80\x93 Machine learning,  Big Data Analytics, Artificial Intelligence  etc.Microwave Image Processing', 'Remote sensing related projects', 'System Dynamics based Approach for Environmental Modelling.Hyperspectral Data Analysis for Characterizing Various Natural Resources (Vegetation, Soil, Water, Air & Mineral)']
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:1418: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
